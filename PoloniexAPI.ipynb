# %%
# !pip3 install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (138 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.7.4 charset-normalizer-3.3.2 idna-3.7 requests-2.32.3 urllib3-2.2.2

# %%
import requests
import json

# %%
# Poloniex Prices
prices = requests.get("https://api.poloniex.com/markets/price")
prices_list = []
if prices.status_code == 200:
  prices_json = json.loads(prices.text)
  for p in prices_json:
    prices_list.append({"ticker": p["symbol"], "price": p["price"]})

# %%
print(prices_list)
# Out:
# [{'ticker': 'BTS_BTC', 'price': '0.0000000328'}, {'ticker': 'DASH_BTC', 'price': '0.000417'}, {'ticker': 'DOGE_BTC', 'price': '0.000001972'}, {'ticker': 'LTC_BTC', 'price': '0.001091'}, {'ticker': 'XLM_BTC', 'price': '0.000001551'}, {'ticker': 'XEM_BTC', 'price': '0.00000022'}, {'ticker': 'XMR_BTC', 'price': '0.002453'}, {'ticker': 'XRP_BTC', 'price': '0.00000935'}, {'ticker': 'BTC_USDT', 'price': '65226'}, {'ticker': 'DASH_USDT', 'price': '26.9'}, {'ticker': 'LTC_USDT', 'price': '70.898'}, {'ticker': 'XLM_USDT', 'price': '0.1021'}, {'ticker': 'XMR_USDT', 'price': '160.13'}, {'ticker': 'XRP_USDT', 'price': '0.6086'}, {'ticker': 'ETH_BTC', 'price': '0.05098'}, {'ticker': 'ETH_USDT', 'price': '3319.65'}, {'ticker': 'SC_BTC', 'price': '0.0000000819'}, {'ticker': 'DCR_BTC', 'price': '0.000181'}, {'ticker': 'LSK_BTC', 'price': '0.00001441'}, {'ticker': 'STEEM_BTC', 'price': '0.00000285'}, {'ticker': 'ETC_BTC', 'price': '0.000349'}, {'ticker': 'ETC_ETH', 'price': '0.00692'}, {'ticker': 'ETC_USDT', 'price': '22.718'}, {'ticker': 'ARDR_BTC', 'price': '0.00000118'}, {'ticker': 'ZEC_BTC', 'price': '0.000457'}, {'ticker': 'ZEC_ETH', 'price': '0.00901'}, {'ticker': 'ZEC_USDT', 'price': '29.98'}, {'ticker': 'ZRX_BTC', 'price': '0.0000056'}, {'ticker': 'ZRX_ETH', 'price': '0.0001064'}, {'ticker': 'CVC_BTC', 'price': '0.000001251'}, {'ticker': 'GAS_BTC', 'price': '0.000057'}, {'ticker': 'STORJ_BTC', 'price': '0.00000571'}, {'ticker': 'EOS_BTC', 'price': '0.00000913'}, {'ticker': 'EOS_ETH', 'price': '0.0001788'}, {'ticker': 'EOS_USDT', 'price': '0.5883'}, {'ticker': 'SNT_BTC', 'price': '0.000000367'}, {'ticker': 'BAT_BTC', 'price': '0.00000303'}, {'ticker': 'BAT_USDT', 'price': '0.1984'}, {'ticker': 'LOOM_BTC', 'price': '0.000000635'}, {'ticker': 'DOGE_USDT', 'price': '0.127583'}, {'ticker': 'LSK_USDT', 'price': '1.0186'}, {'ticker': 'SC_USDT', 'price': '0.005345'}, {'ticker': 'ZRX_USDT', 'price': '0.3687'}, {'ticker': 'QTUM_BTC', 'price': '0.0000391'}, {'ticker': 'QTUM_USDT', 'price': '2.595'}, {'ticker': 'BTC_USDC', 'price': '65513.96'}, {'ticker': 'ETH_USDC', 'price': '3316.09'}, {'ticker': 'USDT_USDC', 'price': '1.00259'}, {'ticker': 'MANA_BTC', 'price': '0.00000521'}, {'ticker': 'MANA_USDT', 'price': '0.3269'}, {'ticker': 'BCHSV_BTC', 'price': '0.000684'}, {'ticker': 'XRP_USDC', 'price': '0.62'}, {'ticker': 'LTC_USDC', 'price': '73.49'}, {'ticker': 'POLY_BTC', 'price': '0.000001001'}, {'ticker': 'ATOM_BTC', 'price': '0.0000925'}, {'ticker': 'ATOM_USDC', 'price': '6.21'}, {'ticker': 'ATOM_USDT', 'price': '6.007'}, {'ticker': 'ETC_USDC', 'price': '22.53'}, {'ticker': 'BCHSV_USDT', 'price': '46.15'}, {'ticker': 'TRX_BTC', 'price': '0.000002058'}, {'ticker': 'TRX_USDC', 'price': '0.13815'}, {'ticker': 'TRX_USDT', 'price': '0.1342'}, {'ticker': 'ETH_TRX', 'price': '24806.19'}, {'ticker': 'XRP_TRX', 'price': '4.529'}, {'ticker': 'BTT_USDT', 'price': '0.0000008655'}, {'ticker': 'BTT_TRX', 'price': '0.00000643'}, {'ticker': 'WIN_USDT', 'price': '0.00008715'}, {'ticker': 'WIN_TRX', 'price': '0.000652'}, {'ticker': 'STEEM_TRX', 'price': '1.733'}, {'ticker': 'LINK_BTC', 'price': '0.000205'}, {'ticker': 'LINK_TRX', 'price': '102.2'}, {'ticker': 'XTZ_USDT', 'price': '0.7424'}, {'ticker': 'USDJ_USDT', 'price': '1.0829'}, {'ticker': 'SNX_BTC', 'price': '0.0000274'}, {'ticker': 'SNX_USDT', 'price': '1.818'}, {'ticker': 'SNX_TRX', 'price': '14.28'}, {'ticker': 'MATIC_BTC', 'price': '0.00000793'}, {'ticker': 'MATIC_USDT', 'price': '0.51619'}, {'ticker': 'MATIC_TRX', 'price': '3.82'}, {'ticker': 'MKR_BTC', 'price': '0.043'}, {'ticker': 'MKR_USDT', 'price': '2697.95'}, {'ticker': 'DAI_USDT', 'price': '0.99949'}, {'ticker': 'NEO_BTC', 'price': '0.0001722'}, {'ticker': 'NEO_USDT', 'price': '11.36'}, {'ticker': 'SWFTC_BTC', 'price': '0.0000000139'}, {'ticker': 'SWFTC_USDT', 'price': '0.001'}, {'ticker': 'JST_USDT', 'price': '0.028587'}, {'ticker': 'JST_TRX', 'price': '0.2139'}, {'ticker': 'STEEM_USDT', 'price': '0.18961'}, {'ticker': 'LINK_USDT', 'price': '13. ...

# %%
# Poloniex Orderbook
ticker = "DASH_BTC"
limit = 20
ob = requests.get(f"https://api.poloniex.com/markets/{ticker}/orderBook?limit={limit}")
ob_json = []
if ob.status_code == 200:
  ob_json = json.loads(ob.text)
print(ob_json)
# Out:
# {'time': 1709746364297, 'scale': '0.000001', 'asks': ['0.000574', '0.3', '0.000598', '0.02', '0.000599', '0.05', '0.0006', '50', '0.000609', '0.15', '0.000628', '0.08', '0.000629', '1.84', '0.000649', '0.05', '0.00065', '30', '0.000651', '2', '0.000658', '0.74', '0.000667', '0.08', '0.000668', '0.99', '0.000679', '0.05', '0.00068', '0.02', '0.000683', '0.05', '0.000684', '0.10', '0.000687', '0.02', '0.000689', '0.10', '0.000694', '0.10'], 'bids': ['0.000504', '5.20', '0.000503', '3.77', '0.000501', '0.04', '0.0005', '0.40', '0.000496', '0.11', '0.00048', '0.06', '0.000461', '0.97', '0.000441', '1.02', '0.00043', '2.75', '0.000421', '1.06', '0.000401', '1.12', '0.00035', '2', '0.000333', '30.03', '0.0003', '3.3', '0.000292', '34.24', '0.0001', '8.91', '0.000054', '36.09', '0.00003', '24', '0.00001', '1334.13', '0.000005', '50'], 'ts': 1709746364602}

# %%
# Structure our orderbook
asks = []
bids = []
for i in range(0, len(ob_json["asks"]), 2):
    ask_price = ob_json["asks"][i]
    ask_quantity = ob_json["asks"][i + 1]
    asks.append([ask_price, ask_quantity])
for i in range(0, len(ob_json["bids"]), 2):
    bid_price = ob_json["bids"][i]
    bid_quantity = ob_json["bids"][i + 1]
    bids.append([bid_price, bid_quantity])
print(asks)
print(bids)
# Out:
# [['0.000574', '0.3'], ['0.000598', '0.02'], ['0.000599', '0.05'], ['0.0006', '50'], ['0.000609', '0.15'], ['0.000628', '0.08'], ['0.000629', '1.84'], ['0.000649', '0.05'], ['0.00065', '30'], ['0.000651', '2'], ['0.000658', '0.74'], ['0.000667', '0.08'], ['0.000668', '0.99'], ['0.000679', '0.05'], ['0.00068', '0.02'], ['0.000683', '0.05'], ['0.000684', '0.10'], ['0.000687', '0.02'], ['0.000689', '0.10'], ['0.000694', '0.10']]
# [['0.000504', '5.20'], ['0.000503', '3.77'], ['0.000501', '0.04'], ['0.0005', '0.40'], ['0.000496', '0.11'], ['0.00048', '0.06'], ['0.000461', '0.97'], ['0.000441', '1.02'], ['0.00043', '2.75'], ['0.000421', '1.06'], ['0.000401', '1.12'], ['0.00035', '2'], ['0.000333', '30.03'], ['0.0003', '3.3'], ['0.000292', '34.24'], ['0.0001', '8.91'], ['0.000054', '36.09'], ['0.00003', '24'], ['0.00001', '1334.13'], ['0.000005', '50']]

# %%
# Binance
symbol = "BTCUSDT"
interval = "1d"
candles = requests.get(f"https://api.binance.com/api/v3/klines?symbol={symbol}&interval={interval}&limit={limit}")
candles_json = []
if candles.status_code == 200:
  candles_json = json.loads(candles.text)
  print(candles_json)

# %%
# Structure close prices
my_candles = []
for c in candles_json:
  my_candles.append(c[4])
print(my_candles)
print(len(my_candles))
# Out:
# []
# 0
